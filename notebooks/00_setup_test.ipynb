# %%
# Phase 00 — Environment Check

Goal: verify that Jupyter is running from the project virtual environment (.venv) and core packages are available.

# %%
print("hey")
# Out:
# hey

# %%
import sys, platform
print("Python:", sys.version)
print("Executable:", sys.executable)
print("Platform:", platform.platform())
# Out:
# Python: 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]
# Executable: C:\Users\gbarr\proyectos\ai-master-roadmap\.venv\Scripts\python.exe
# Platform: Windows-11-10.0.26200-SP0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
# Out:
# numpy: 2.4.2
# pandas: 3.0.0
